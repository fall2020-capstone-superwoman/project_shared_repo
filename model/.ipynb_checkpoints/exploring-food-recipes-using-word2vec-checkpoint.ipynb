# %%
import pandas as pd
import numpy as np
import collections
import gensim 
from gensim.models import word2vec, phrases
from gensim.parsing.preprocessing import remove_stopwords, strip_punctuation, strip_numeric,\
                    strip_non_alphanum, strip_multiple_whitespaces, strip_short
from textblob import TextBlob, Word

import re
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
# %matplotlib inline

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\wen\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
#load the recipes dataset
filepath = "recipesall.csv"
df_recipes = pd.read_csv(filepath, encoding="ISO-8859-1")

#drop rows where cuisine, ingregients are NA
df_recipes.dropna(subset=['cuisine', 'ingredients'],inplace=True)
df_recipes
# Out:
#                                                      id  \
# 0                   Southern-Cornbread-Dressing-1357820
# 1                            Peanut-butter-fudge-297693
# 2                                       Buckeyes-298471
# 3               Disappearing-buffalo-chicken-dip-297712
# 4                         Classic-macaroni-salad-304692
# 5                               Classic-coleslaw-303481
# 6                                 Bechamel-Sauce-513101
# 7                        Peanut-butter-cream-pie-298882
# 8                            Southern-Pecan-Pie-1332202
# 9                            Peanut-Butter-Fudge-482257
# 10    Buffalo-Turkey-Burgers-with-Buffalo-Blue-Chees...
# 11                         Best-Homemade-Brownie-514487
# 12                               Creamed-spinach-305542
# 13                      Eggs-in-hash-brown-nests-352693
# 14                               Enchilada-Sauce-472402
# 15                        Home-Fries-Real-Simple-199083
# 16          Blueberry-Simple-Syrup-Closet-Cooking-54900
# 17                         Some-People-Need-Wine-474670
# 18                          Brown-sugar-meatloaf-368833
# 19    Maryland-Crab-Cakes-with-Quick-Tartar-Sauce-On...
# 20                Bacon-and-Brussel-Sprout-Salad-499392
# 21    Skinny-buttermilk-mashed-potatoes-with-chives-...
# 22                     Hot-roast-beef-sandwiches-345284
# 23                 Cranberry-brie-grilled-cheese-309053
# 24    Roasted-red-pepper-_-bacon-goat-cheese-truffle...
# 25             Roasted-corn-with-cilantro-butter-351940
# 26                              Huevos-rancheros-370964
# 27    Thanksgiving-breakfast-hash-with-cheddar-mashe...
# 28                              Homemade-ketchup-352104
# 29                         Homemade-Tartar-Sauce-513062
# ...                                                 ...
# 5444                           Teriyaki-Chicken-1170639
# 5445  Yakitori-_Japanese-Grilled-Skewered-Chicken_-4...
# 5446     Yakitori-__---Japanese-Grilled-Chicken-1173562
# 5447       Japanese-Spinach-with-Sesame-and-Soy-1299741
# 5448             Japanese-pancakes-_okonomiyaki_-306541
# 5449                                Unagi-Sauce-1283864
# 5450                     Japanese-Sushi-Rice-Allrecipes
# 5451                       Udon-miso-noodle-soup-315064
# 5452           Onigiri-_-Japanese-Rice-Balls-AllRecipes
# 5453        Japanese-Sesame-Miso-Grilled-Salmon-1198712
# 5454                               Beef-Teriyaki-496825
# 5455         Protein-Packed-Japanese-Tofu-Steak-1314305
# 5456  Not-Fried-Shrimp-with-Japanese-Cocktail-Sauce-...
# 5457  Teriyaki-Salmon-Rice-Bowl-with-Spinach-_-Avoca...
# 5458  Japanese-Fried-Chicken-Chicken-Karaage-_-_-104...
# 5456      Not-Fried Shrimp with Japanese Cocktail Sauce     3.0
# 5457   Teriyaki Salmon Rice Bowl with Spinach & Avocado     4.0
# 5458  Japanese Fried Chicken  Chicken Karaage ( ?? ...     3.0
# 5459             Tonkatsu recipe (Japanese pork cutlet)     3.0
# 5460  Japanese Marinated Soft Boiled Egg for Ramen (...     5.0
# 5461                                Japanese Beef Rolls     4.0
# 5462                                        Ponzu Sauce     4.0
# 5463                                Yaki Udon With Beef     4.0
# 5464  Turmeric-Miso Soup with Shiitakes, Turnips, an...     3.0
# 5465                             Detox Teriyaki Chicken     3.0
# 5466                                 Perfect Sushi Rice     5.0
# 5467                       Japanese Grilled Miso Salmon     4.0
# 5468                             Japanese Fried Chicken     4.0
# 5469                                   Chicken Teriyaki     4.0
# 5470                                          Miso Soup     4.0
# 5471         Miso Marinated Pork (butaniku no misozuke)     4.0
# 5472      Japanese Street Food Recipe - Chicken Karaage     4.0
# 5473                                              Ponzu     4.0
#
#       totalTimeInSeconds                                             course  \
# 0                 3600.0                                                NaN
# 1                 8100.0                                         [Desserts]
# 2                 6600.0                                         [Desserts]
# 3                 2100.0                                       [Appetizers]
# 4                 1500.0                              [Salads, Side Dishes]
# 5                  600.0                              [Salads, Side Dishes]
# 6                 1200.0                            [Condiments and Sauces]
# 7                11700.0                                         [Desserts]
# 8                 4800.0                                         [Desserts]
# 9                  600.0                                         [Desserts]
# 10                1380.0                                      [Main Dishes]
# 11                5100.0                                         [Desserts]
# 12                2700.0                                      [Side Dishes]
# 13                   NaN                             [Breakfast and Brunch]
# 14                2100.0                            [Condiments and Sauces]
# 15                1800.0  [Lunch and Snacks, Side Dishes, Breakfast and ...
# 16                1800.0  [Beverages, Breakfast and Brunch, Condiments a...
# 17                1800.0                                         [Desserts]
# 18                1800.0                                      [Main Dishes]
# 19                5100.0                          [Appetizers, Main Dishes]
# 20                1500.0                                           [Salads]
# 21                   NaN                                      [Side Dishes]
# 22                1800.0                                 [Lunch and Snacks]
# 23                1200.0                     [Appetizers, Lunch and Snacks]
# 24                2700.0                                       [Appetizers]
# 25                2700.0                                      [Side Dishes]
# 26                2400.0           [Breakfast and Brunch, Lunch and Snacks]
# 27                1200.0                             [Breakfast and Brunch]
# 28                   NaN                            [Condiments and Sauces]
# 29                1200.0                            [Condiments and Sauces]
# ...                  ...                                                ...
# 5444               600.0                                      [Main Dishes]
# 5445              2700.0                                                NaN
# 5446              2700.0                                                 []
# 5447              2700.0                                                NaN
# 5448              3000.0                                                NaN
# 5449              1200.0                            [Condiments and Sauces]
# 5450              2100.0                                                NaN
# 5451              2100.0                                            [Soups]
# 5452              4200.0                                 [Lunch and Snacks]
# 5453              1500.0                                      [Main Dishes]
# 5454              2100.0                                      [Main Dishes]
# 5455              1500.0                                      [Main Dishes]
# 5456              1500.0                                                 []
# 5457              4200.0                                      [Main Dishes]
# 5458              6300.0                                      [Main Dishes]
# 5459              2100.0                                      [Main Dishes]
# 5460                 NaN                                                NaN
# 5461              1800.0                                                NaN
# 5462              1500.0                            [Condiments and Sauces]
# 5463              3000.0                                      [Main Dishes]
# 5464              3000.0                                            [Soups]
# 5465              2400.0                                      [Main Dishes]
# 5466              3000.0                                                 []
# 5467               900.0                                      [Main Dishes]
# 5468              1200.0                                      [Main Dishes]
# 5469              2700.0                                      [Main Dishes]
# 5470               600.0                                            [Soups]
# 5471              2400.0                                      [Main Dishes]
# 5472              2700.0                                      [Main Dishes]
# 5473               600.0                            [Condiments and Sauces]
#
#                                 cuisine  \
# 0                [Southern & Soul Food]
# 1                            [American]
# 2                            [American]
# 3                            [American]
# 4                            [American]
# 5      [American, Southern & Soul Food]
# 6                    [American, French]
# 7                            [American]
# 8      [Southern & Soul Food, American]
# 9                            [American]
# 10                           [American]
# 11                           [American]
# 12                           [American]
# 13                           [American]
# 14                  [American, Mexican]
# 15                           [American]
# 16                           [American]
# 17                           [American]
# 18                           [American]
# 19                           [American]
# 20                           [American]
# 21                           [American]
# 22                           [American]
# 23                           [American]
# 24                           [American]
# 25                           [American]
# 26    [American, Mexican, Southwestern]
# 27                           [American]
# 28                           [American]
# 29                           [American]
# ...                                 ...
# 5444                         [Japanese]
# 5445                  [Asian, Japanese]
# 5446                  [Japanese, Asian]
# 5447                  [Japanese, Asian]
# 5448                  [Asian, Japanese]
# 5449                  [Japanese, Asian]
# 5450                  [Japanese, Asian]
# 5451                  [Japanese, Asian]
# 5452                  [Japanese, Asian]
# 5453                         [Japanese]
# 5454                  [Asian, Japanese]
# 5455                  [Japanese, Asian]
# 5456                         [Japanese]
# 5457                  [Japanese, Asian]
# 5458                         [Japanese]
# 5459                  [Asian, Japanese]
# 5460                         [Japanese]
# 5461                         [Japanese]
# 5462                         [Japanese]
# 5463                  [Asian, Japanese]
# 5464                  [Japanese, Asian]
# 5465                         [Japanese]
# 5466                         [Japanese]
# 5467               [Barbecue, Japanese]
# 5468                  [Japanese, Asian]
# 5469                         [Japanese]
# 5470                         [Japanese]
# 5471                         [Japanese]
# 5472                  [Japanese, Asian]
# 5473                  [Japanese, Asian]
#
#                                             ingredients
# 0     [buttermilk cornbread, sandwich bread, salt, b...
# 1     [Country Crock® Spread, light corn syrup, crea...
# 2     [Skippy® Super Chunk® Peanut Butter, Country C...
# 3     [light mayonnaise, lemon juice, cayenne pepper...
# 4     [elbow macaroni, hellmann' or best food real m...
# 5     [hellmann' or best food real mayonnais, lemon ...
# 6     [2% reduced-fat milk, unsalted butter, all pur...
# 7     [Skippy Creamy Peanut Butter, sugar, cream che...
# 8     [pie crust, eggs, light corn syrup, butter, li...
# 9     [unsalted butter, creamy peanut butter, salt, ...
# 10    [lean ground turkey, hot sauce, ranch-style se...
# 11    [butter, chocolate, sugar, vanilla extract, eg...
    all_ingredients = list()
    
    #split each recipe into different ingredients
    ingred = df_recipes.loc[i, "ingredients"][1:-1]
    
    for ing in (ingred.split(',')):
        ing = remove_stopwords(ing)
        ing = strip_numeric(ing)
        ing = re.sub(r'\(.*oz.\)|(®)|(.*ed)|(.*ly)|boneless|skinless|chunks|fresh|large|cook drain|green|frozen|ground','',ing).strip()
        ing = strip_short(ing,2)
        ing = strip_multiple_whitespaces(ing)
        ing = strip_punctuation(ing)
        ing = strip_non_alphanum(ing)
        
        #convert plurals to singular e.g. tomatoes --> tomato
        ing = (" ".join(TextBlob(ing).words.singularize()))
        
        all_ingredients.append(ing)
        total_ingredients.append(ing)
        
    all_receipes_ingredients.append(all_ingredients)
    
counts_ingr = collections.Counter(total_ingredients)

print('Total Ingredients (with repetition):  \t{}'.format((len(total_ingredients))))
print('Unique Ingredients : \t\t\t{}'.format((len(counts_ingr.values()))))
print('Total Receipes:  \t\t\t{}'.format((len(all_receipes_ingredients))))
# Out:
# Total Ingredients (with repetition):  	55047
# Unique Ingredients : 			2633
# Total Receipes:  			5474

# %%
#add cleaned ingredients back to original dataframe
df_recipes['clean_ingredients'] = pd.Series(all_receipes_ingredients)

#record the number of ingredients for each recipe
df_recipes['ingredient_count'] =  df_recipes.apply(lambda row: len(row['clean_ingredients']), axis = 1)

#convert time in seconds to minutes
df_recipes['timeMins'] = df_recipes.totalTimeInSeconds.apply(lambda x: x/60)

# %%
print(np.mean(list(counts_ingr.values())))
print(np.std(list(counts_ingr.values())))
print(np.median(list(counts_ingr.values())))
print(np.percentile(list(counts_ingr.values()), [25., 50., 75., 99.]))
# Out:
# 20.906570451955943
# 99.1628173432985
# 2.0
# [  1.     2.     7.   378.36]

# %%
#find the most common ingredients used across all recipes
print ("---- Most Common Ingredients ----")
print (counts_ingr.most_common(10))

print ("\n")

#find the most common ingredients used across all recipes
print ("---- Least Common Ingredients ----")
print (counts_ingr.most_common()[-10:])
# Out:
# ---- Most Common Ingredients ----
# [('salt', 2377), ('onion', 1794), ('garlic', 1484), ('pepper', 1208), ('butter', 1160), ('black pepper', 1020), ('sugar', 1019), ('olive oil', 897), ('water', 881), ('egg', 845)]
#
#
# ---- Least Common Ingredients ----
# [('orecchiette', 1), ('gorgonzola', 1), ('ciabattum bun', 1), ('bertolli', 1), ('liquid egg substitute', 1), ('delallo extra virgin olive oil', 1), ('sourdough baguette', 1), ('mentsuyu', 1), ('canola oil cooking spray', 1), ('wakame', 1)]

# %%
#visualize the ingredients in WordCloud 

from wordcloud import WordCloud

def plot_wordcloud(text, title=None, max = 1000, size=(12,8), title_size=16):
    """plots wordcloud"""
    wordcloud = WordCloud(max_words=max).generate(text)
    plt.figure(figsize=size)
    plt.title(title, size=title_size)
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")

plot_wordcloud(' '.join(total_ingredients), title='Ingredients')

# %%
#Train the Word2Vec model

num_features = 300    # Word vector dimensionality                      
min_word_count = 4                        
num_workers = 4       # Number of CPUs
context = 10          # Context window size; 

downsampling = 1e-2   # threshold for configuring which 
                      # higher-frequency words are randomly downsampled
            
# Initialize and train the model 
model = word2vec.Word2Vec(all_receipes_ingredients, workers=num_workers, \
            size=num_features, min_count = min_word_count, \
            window = context,sample = downsampling, iter=20)

# If you don't plan to train the model any further, calling 
# init_sims will make the model much more memory-efficient.
model.init_sims(replace=True)

# %%
# check the similar ingredients returned by the model for search_terms

similar_words = {search_term: [item[0] for item in model.wv.most_similar([search_term], topn=5)]
                  for search_term in ['paneer','egg','mango','bread', 'rice']}
similar_words
# Out:
# {'paneer': ['garlic paste',
#   'ginger paste',
#   'masala',
#   'chile powder',
#   'mutton'],
#  'egg': ['beaten egg', 'egg white', 'dough', 'egg yolk', 'sirloin steak'],
#  'mango': ['club soda', 'light rum', 'mint leaf', 'white rum', 'lime juice'],
#  'bread': ['italian cheese blend',
#   'pepperoni',
#   'part skim mozzarella cheese',
#   'penne pastum',
#   'provolone cheese'],
#  'rice': ['brown rice',
#   'white rice',
#   'long grain rice',
#   'beansprout',
#   'mung bean sprout']}

# %%
#visualization with Tsne
from sklearn.manifold import TSNE

words = sum([[k] + v for k, v in similar_words.items()], [])
wvs = model.wv[words]
tsne = TSNE(n_components=2, random_state=0, n_iter=1000, perplexity=2)
np.set_printoptions(suppress=True)
T = tsne.fit_transform(wvs)
labels = words

plt.figure(figsize=(14, 8))
plt.scatter(T[:, 0], T[:, 1], c='orange', edgecolors='r')
for label, x, y in zip(labels, T[:, 0], T[:, 1]):
    plt.annotate(label, xy=(x+1, y+1), xytext=(0, 0), textcoords='offset points')

# %%
model.wv.most_similar_cosmul(positive=['paneer', u'chicken'], negative=['tomato sauce'])
# Out:
# [('corn flmy', 2.6962008476257324),
#  ('szechwan peppercorn', 2.4917855262756348),
#  ('udon', 2.276217460632324),
#  ('bean paste', 2.228572368621826),
#  ('cashew nut', 2.222132921218872),
#  ('chicken thigh fillet', 2.186232089996338),
#  ('rice flmy', 2.138754367828369),
#  ('star anise', 2.133235454559326),
#  ('coconut', 1.9562902450561523),
#  ('white miso', 1.9529191255569458)]

# %%
model.wv.most_similar('chocolate')
# Out:
# [('cocoa powder', 0.9658623933792114),
#  ('semisweet chocolate', 0.9632582068443298),
#  ('dark chocolate', 0.9607710838317871),
#  ('vanilla bean', 0.9547520875930786),
#  ('cocoa', 0.9519894123077393),
#  ('light corn syrup', 0.9469964504241943),
#  ('ladyfinger', 0.9458081722259521),
#  ('coffee', 0.9444921612739563),
#  ('lemon extract', 0.9434249401092529),
#  ('vanilla sugar', 0.936489999294281)]

# %%
model.wv.most_similar('mayonnaise')
# Out:
# [('cheese', 0.763910174369812),
#  ('creole mustard', 0.6974138021469116),
#  ('mozzarella cheese', 0.648257315158844),
#  ('breadcrumb', 0.6403073668479919),
#  ('cream cheese', 0.6344897747039795),
#  ('pickle', 0.631036639213562),
#  ('part skim mozzarella cheese', 0.6284791827201843),
#  ('horseradish', 0.6252840757369995),
#  ('pizza crust', 0.6246763467788696),
#  ('blue cheese', 0.6126261949539185)]

# %%
model.wv.most_similar('chicken')
# Out:
# [('chicken thigh', 0.6965686082839966),
#  ('chicken breast', 0.6575872898101807),
#  ('vegetable broth', 0.6188830137252808),
#  ('chily', 0.5993492603302002),
#  ('chile pepper', 0.5885477662086487),
#  ('cilantro leaf', 0.5695962905883789),
#  ('chili pepper', 0.5636962652206421),
#  ('shiitake mushroom', 0.534757137298584),
#  ('pumpkin', 0.5307385325431824),
#  ('chicken broth', 0.5182914137840271)]

# %%
model.wv.most_similar('broccoli')
# Out:
# [('broccoli floret', 0.7705859541893005),
#  ('shiitake mushroom', 0.7533687353134155),
#  ('dry roast peanut', 0.7258435487747192),
#  ('beef sirloin', 0.7253038287162781),
#  ('chinese rice wine', 0.7183657288551331),
#  ('snow pea', 0.7135268449783325),
#  ('spring onion', 0.7075238227844238),
#  ('shiitake', 0.7064124941825867),
#  ('firm tofu', 0.7041536569595337),
#  ('oyster sauce', 0.6971466541290283)]

# %%
model.wv.most_similar('shrimp')
# Out:
# [('ium shrimp', 0.6962401866912842),
#  ('chicken broth', 0.6689896583557129),
#  ('chicken stock', 0.6605052351951599),
#  ('low sodium chicken broth', 0.6488544940948486),
#  ('cajun seasoning', 0.609250545501709),
#  ('okra', 0.6015691757202148),
#  ('creole seasoning', 0.5966904163360596),
#  ('celery', 0.5955643057823181),
#  ('andouille sausage', 0.5955514907836914),
#  ('bell pepper', 0.5862600803375244)]

# %%
model.wv.similarity('paneer', 'chicken')

# %%
model.wv.doesnt_match("chicken paneer lentils meat".split())

# %%
model.wv.similarity('chocolate', 'cream')

# %%
x = 'bread'
b= 'cheese'
a = 'bread'
predicted = model.wv.most_similar([x, b], [a])[0][0]
print(" {} is to  {} as {} is to {} ".format(a, b, x, predicted))

# %%
plt.style.available
plt.style.use('ggplot')

plt.xlabel('Cooking Time (minutes)')
plt.ylabel('Recipe Count')

labels = ['4', '3', '5', '0', '2', '1']
plt.pie(df_recipes.rating.value_counts(), labels=labels, autopct='%1.1f%%', colors=['gold', 'green', 'lightcoral', 'lightskyblue', 'red'], startangle=50, pctdistance=0.6)
plt.axis('equal')
plt.title('Recipes by Rating')
plt.show()

# %%
# ingredient/rating relationship?

feature_cols = ['ingredient_count']
X= df_recipes[feature_cols]
y= df_recipes.rating
plt.scatter(X, y)
plt.xlabel('Ingredients')
plt.ylabel('Yummly Rating')
plt.title('Ingredient Counts vs Ratings')

# %%
feature_cols = ['timeMins']
X= df_recipes.dropna()[feature_cols]
y= df_recipes.dropna().rating
plt.scatter(X, y)
plt.xlabel('Time in Minutes')
plt.ylabel('Yummly Rating')
plt.title('Cooking Time vs Ratings')

# %%
# ingredients/cooking time relationship?
feature_cols = ['ingredient_count']
X= df_recipes.dropna()[feature_cols]
y= df_recipes.dropna()['timeMins']
plt.scatter(X, y)
plt.xlabel('Ingredient Count')
plt.ylabel('Time in Minute')
plt.title('Ingredients vs. Cooking Times')

# %%
df_indian = df_recipes[df_recipes.cuisine.str.contains("indian", case=False)].copy()

ingredients =df_indian["clean_ingredients"].sum()

counts = collections.Counter(ingredients)

counts.most_common(30)
